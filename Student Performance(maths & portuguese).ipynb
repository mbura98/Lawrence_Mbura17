# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
por_df=pd.read_csv(r'C:\Users\ADMIN\Desktop\student-por.csv', sep=';')
mat_df=pd.read_csv(r'C:\Users\ADMIN\Desktop\student-mat.csv', sep=';')

# %%
por_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
mat_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# MERGING THE TWO DATASETS

# %%
common_columns = ['school','sex','age','address','famsize','Pstatus','Medu','Fedu','Mjob','Fjob','reason','nursery','internet']

df = pd.merge(mat_df, por_df, on=common_columns, suffixes=('_mat_df','_por_df'))

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel_por_df freetime_por_df  goout_por_df  Dalc_por_df  Walc_por_df  \
# 0             4               3             4            1            1
# 1             5               3             3            1            1
# 2             4               3             2            2            3
# 3             3               2             2            1            1
# 4             4               3             2            1            2
#
#   health_por_df absences_por_df G1_por_df G2_por_df G3_por_df
# ...

# %% [markdown]
# MISSING VALUES IN THE DATASET

# %%
df.isnull().sum()
# Out:
# school               0
# sex                  0
# age                  0
# address              0
# famsize              0
# Pstatus              0
# Medu                 0
# Fedu                 0
# Mjob                 0
# Fjob                 0
# reason               0
# guardian_mat_df      0
# traveltime_mat_df    0
# studytime_mat_df     0
# failures_mat_df      0
# schoolsup_mat_df     0
# famsup_mat_df        0
# paid_mat_df          0
# activities_mat_df    0
# nursery              0
# higher_mat_df        0
# internet             0
# romantic_mat_df      0
# famrel_mat_df        0
# freetime_mat_df      0
# goout_mat_df         0
# Dalc_mat_df          0
# Walc_mat_df          0
# health_mat_df        0
# absences_mat_df      0
# G1_mat_df            0
# G2_mat_df            0
# G3_mat_df            0
# guardian_por_df      0
# traveltime_por_df    0
# studytime_por_df     0
# failures_por_df      0
# schoolsup_por_df     0
# famsup_por_df        0
# paid_por_df          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 53 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             382 non-null    object
#  1   sex                382 non-null    object
#  2   age                382 non-null    int64
#  3   address            382 non-null    object
#  4   famsize            382 non-null    object
#  5   Pstatus            382 non-null    object
#  6   Medu               382 non-null    int64
#  7   Fedu               382 non-null    int64
#  8   Mjob               382 non-null    object
#  9   Fjob               382 non-null    object
#  10  reason             382 non-null    object
#  11  guardian_mat_df    382 non-null    object
#  12  traveltime_mat_df  382 non-null    int64
#  13  studytime_mat_df   382 non-null    int64
#  14  failures_mat_df    382 non-null    int64
#  15  schoolsup_mat_df   382 non-null    object
# ...

# %%
df['school'].value_counts()
# Out:
# school
# GP    342
# MS     40
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# F    198
# M    184
# Name: count, dtype: int64

# %% [markdown]
# ADDRESS FOR STUDENTS. U-URBAN, R-RURAL

# %%
df['address'].value_counts()
# Out:
# address
# U    301
# R     81
# Name: count, dtype: int64

# %%
df['famsize'].value_counts()
# Out:
# famsize
# GT3    278
# LE3    104
# Name: count, dtype: int64

# %% [markdown]
# NUMBER OF COHABILITATION STATUS T- TOGETHER OR A- APART

# %%
df['Pstatus'].value_counts()
# Out:
# Pstatus
# T    344
# A     38
# Name: count, dtype: int64

# %% [markdown]
# MOTHERS JOB

# %%
df['Mjob'].value_counts()
# Out:
# Mjob
# other       138
# services     96
# teacher      62
# at_home      53
# health       33
# Name: count, dtype: int64

# %% [markdown]
# FATHERS JOB

# %%
df['Fjob'].value_counts()
# Out:
# Fjob
# other       211
# services    107
# teacher      31
# health       17
# at_home      16
# Name: count, dtype: int64

# %% [markdown]
# REASON TO CHOOSE THE SCHOOL

# %%
df['reason'].value_counts()
# Out:
# reason
# course        140
# home          110
# reputation     98
# other          34
# Name: count, dtype: int64

# %% [markdown]
# STUDENTS ATTENDED NURSERY SCHOOL

# %%
df['nursery'].value_counts()
# Out:
# nursery
# yes    310
# no      72
# Name: count, dtype: int64

# %% [markdown]
# INTERNET ACCESS AT HOME

# %%
df['internet'].value_counts()
# Out:
# internet
# yes    324
# no      58
# Name: count, dtype: int64

# %% [markdown]
# ADDRESS OF STUDENTS BASED ON SEX

# %%
df.groupby('sex')['address'].value_counts()
# Out:
# sex  address
# F    U          157
#      R           41
# M    U          144
#      R           40
# Name: count, dtype: int64

# %% [markdown]
# STUDENT'S SEX BASED ON THIER FATHERS JOB

# %%
df.groupby('sex')['Fjob'].value_counts()
# Out:
# sex  Fjob
# F    other       107
#      services     56
#      teacher      13
#      at_home      11
#      health       11
# M    other       104
#      services     51
#      teacher      18
#      health        6
#      at_home       5
# Name: count, dtype: int64

# %% [markdown]
# STUDENT'S SEX BASED ON THIER MOTHERS JOB

# %%
df.groupby('sex')['Mjob'].value_counts()
# Out:
# sex  Mjob
# F    other       75
#      services    47
#      at_home     38
#      teacher     20
#      health      18
# M    other       63
#      services    49
#      teacher     42
#      at_home     15
#      health      15
# Name: count, dtype: int64

# %%
df.groupby('address')[['Fjob','internet']].value_counts()
# Out:
# address  Fjob      internet
# R        other     yes          32
#          services  yes          17
#          other     no           15
#          services  no            6
#          teacher   yes           4
#          at_home   yes           2
#          health    yes           2
#          teacher   no            2
#          at_home   no            1
# U        other     yes         141
#          services  yes          82
#          other     no           23
#          teacher   yes          21
#          at_home   yes          12
#          health    yes          11
#                    no            4
#          teacher   no            4
#          services  no            2
#          at_home   no            1
# Name: count, dtype: int64

# %%
def countplots(col):
    sns.countplot(df[col])
    plt.show()

# %%
for i in list(df.select_dtypes(exclude=['int']).columns):
    countplots(i)
