# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\ADMIN\Desktop\DATASETS\Telecom Customers Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# NUMBER OF CUSTOMER GENDER

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %% [markdown]
# NUMBER OF CUSTOMER SENIOR CITIZEN

# %%
df['SeniorCitizen'].value_counts()
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %% [markdown]
# NUMBER OF CUSTOMER WITH PARTNERS

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %% [markdown]
# NUMBER FOR DEPENDENTS

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %% [markdown]
# NUMBER OF DEPENDENTS BASED ON GENDER

# %%
df.groupby('gender')['Dependents'].value_counts()
# Out:
# gender  Dependents
# Female  No            2460
#         Yes           1028
# Male    No            2473
#         Yes           1082
# Name: count, dtype: int64

# %% [markdown]
# TYPE OF INTERNET SERVICES FOR CUSTOMERS

# %%
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %% [markdown]
# COUNT OF DEVICE PROTECTION

# %%
df['DeviceProtection'].value_counts()
# Out:
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %% [markdown]
# CUSTOMERS WITH TECH SUPPORT

# %%
df['TechSupport'].value_counts()
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %% [markdown]
# CUSTOMERS THAT HAVE STREAMING TV

# %%
df['StreamingTV'].value_counts()
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %% [markdown]
# NUMBER OF CUSTOMERS THAT ARE STREAMING MOVIES

# %%
df['StreamingMovies'].value_counts()
# Out:
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %% [markdown]
# CONTRACT TYPE

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %% [markdown]
# PAYMENT METHOD

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
def distplots(col):
    sns.distplot(df[col])
    plt.show()

# %%
for i in list(df.select_dtypes(exclude=['object']).columns):
    distplots(i)

# %%
def countplots(col):
    sns.countplot(df[col])
    plt.show()

# %%
for i in list(df.select_dtypes(exclude=['int']).columns):
    countplots(i)

# %% [markdown]
# Top 5 Customers with the highest Total Charges

# %%
df.sort_values('TotalCharges', ascending=False).head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2845  9093-FPDLG  Female              0      No         No      11
# 3353  4536-PLEQY    Male              0     Yes         No      12
# 3686  5899-MQZZL  Female              0      No         No      13
# 5598  6051-PTVNS  Female              0     Yes        Yes      55
# 6646  8249-THVEC    Male              0     Yes        Yes      51
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2845          Yes            No     Fiber optic                   No  ...
# 3353          Yes            No     Fiber optic                   No  ...
# 3686          Yes           Yes     Fiber optic                   No  ...
# 5598          Yes            No              No  No internet service  ...
# 6646          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
enco=LabelEncoder()
df['Churn']=enco.fit_transform(df['Churn'])
df['gender']=enco.fit_transform(df['gender'])
df['SeniorCitizen']=enco.fit_transform(df['SeniorCitizen'])
df['Partner']=enco.fit_transform(df['Partner'])
df['Dependents']=enco.fit_transform(df['Dependents'])
df['PhoneService']=enco.fit_transform(df['PhoneService'])
df['MultipleLines']=enco.fit_transform(df['MultipleLines'])
df['InternetService']=enco.fit_transform(df['InternetService'])
df['OnlineSecurity']=enco.fit_transform(df['OnlineSecurity'])
df['OnlineBackup']=enco.fit_transform(df['OnlineBackup'])
df['DeviceProtection']=enco.fit_transform(df['DeviceProtection'])
df['TechSupport']=enco.fit_transform(df['TechSupport'])
df['StreamingTV']=enco.fit_transform(df['StreamingTV'])
df['StreamingMovies']=enco.fit_transform(df['StreamingMovies'])
df['Contract']=enco.fit_transform(df['Contract'])
df['PaperlessBilling']=enco.fit_transform(df['PaperlessBilling'])
df['PaymentMethod']=enco.fit_transform(df['PaymentMethod'])
df['MonthlyCharges']=enco.fit_transform(df['MonthlyCharges'])
df['TotalCharges']=enco.fit_transform(df['TotalCharges'])

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
x=df.drop('Churn', axis=1)
y=df['Churn']

# %%
from sklearn.preprocessing import StandardScaler
sca=StandardScaler()
x=sca.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
lreg=LogisticRegression()
lreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
yhat_train_lreg=lreg.predict(x_train)
yhat_test_lreg=lreg.predict(x_test)

# %%
print(classification_report(y_train, yhat_train_lreg))
print()
print(classification_report(y_test,yhat_test_lreg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      4113
#            1       0.67      0.55      0.61      1521
#
#     accuracy                           0.81      5634
#    macro avg       0.76      0.73      0.74      5634
# weighted avg       0.80      0.81      0.80      5634
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      1061
#            1       0.63      0.52      0.57       348
#
#     accuracy                           0.81      1409
#    macro avg       0.74      0.71      0.72      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
print(confusion_matrix(y_train, yhat_train_lreg))
print()
print(confusion_matrix(y_test, yhat_test_lreg))
# Out:
# [[3695  418]
#  [ 680  841]]
#
# [[955 106]
#  [166 182]]

# %%
c_matrix=ConfusionMatrixDisplay(confusion_matrix(yhat_train_lreg, y_train))
c_matrix.plot(cmap='coolwarm')

# %%
c_matrix=ConfusionMatrixDisplay(confusion_matrix(yhat_test_lreg, y_test))
c_matrix.plot(cmap='viridis')

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(lreg, x, y, cv=3)
np.mean(scores)
# Out:
# 0.8049133367545215

# %% [markdown]
# RANDOM FOREST CLASSIFIER MODEL

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
yhat_train_rfc=rfc.predict(x_train)
yhat_test_rfc=rfc.predict(x_test)

# %%
print(classification_report(y_train, yhat_train_rfc))
print()
print(classification_report(y_test, yhat_test_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4113
#            1       1.00      1.00      1.00      1521
#
#     accuracy                           1.00      5634
#    macro avg       1.00      1.00      1.00      5634
# weighted avg       1.00      1.00      1.00      5634
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88      1061
#            1       0.64      0.47      0.54       348
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.69      0.71      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
print(confusion_matrix(y_train,yhat_train_rfc))
print()
print(confusion_matrix(y_test,yhat_test_rfc))
# Out:
# [[4108    5]
#  [   7 1514]]
#
# [[969  92]
#  [184 164]]

# %%
c_matrix=ConfusionMatrixDisplay(confusion_matrix(yhat_train_rfc, y_train))
c_matrix.plot(cmap='coolwarm')
plt.show()

# %%
c_matrix=ConfusionMatrixDisplay(confusion_matrix(yhat_test_rfc, y_test))
c_matrix.plot(cmap='viridis')
plt.show()

# %%
scores=cross_val_score(rfc, x, y, cv=3)
np.mean(scores)
# Out:
# 0.7952575532891192
